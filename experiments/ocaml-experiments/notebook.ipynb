# %%
import numpy as np 
import pandas as pd 
import json
import os

# %%
PARSED_FILE = './parsed.json'
with open(PARSED_FILE, 'r') as json_file:
    data = json.load(json_file)

# Create a DataFrame from the list of dictionaries
df = pd.json_normalize(data)
df
# Out:
#     workload  discards  foundbug            strategy    mutant  passed  \
# 0        BST       615     False  typeBasedGenerator  insert_3     585
# 1        BST       585     False  typeBasedGenerator  insert_3     615
# 2        BST       599     False  typeBasedGenerator  insert_3     601
# 3        BST       574     False  typeBasedGenerator  insert_3     626
# 4        BST       567     False  typeBasedGenerator  insert_3     633
# ..       ...       ...       ...                 ...       ...     ...
# 525      BST        17      True  typeBasedGenerator  insert_1      10
# 526      BST         0      True  typeBasedGenerator  insert_1       1
# 527      BST         5      True  typeBasedGenerator  insert_1       4
# 528      BST         0      True  typeBasedGenerator  insert_1       2
# 529      BST         0      True  typeBasedGenerator  insert_1       1
#
#               property    time
# 0    prop_InsertDelete   98.46
# 1    prop_InsertDelete  156.44
# 2    prop_InsertDelete  113.41
# 3    prop_InsertDelete  101.26
# 4    prop_InsertDelete  106.22
# ..                 ...     ...
# 525   prop_InsertModel    4.38
# 526   prop_InsertModel    0.22
# 527   prop_InsertModel    2.75
# 528   prop_InsertModel    0.28
# 529   prop_InsertModel    0.21
#
# [530 rows x 8 columns]
